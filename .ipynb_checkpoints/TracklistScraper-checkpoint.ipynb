# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-f3659517c690> in <module>
#       2 import pandas as pd
#       3 import requests
# ----> 4 import unidecode
#
# ModuleNotFoundError: No module named 'unidecode'

# %%
headers = {'User-Agent': 'Mozilla/5.0'}
page_link  = 'https://www.1001tracklists.com/tracklist/cbzj0gt/diplo-made-in-america-festival-united-states-2018-09-02.html'
page_response = requests.get(page_link, headers=headers)
soup = BeautifulSoup(page_response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Article" lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta content="charset=UTF-8"/>
#   <title>
#    Diplo @ Made In America Festival, United States 2018-09-02
#   </title>
#   <meta content="1001Tracklists" name="author"/>
#   <meta content="Tracklist / Playlist for Diplo @ Made In America Festival, United States 2018-09-02, 122 tracks, 1h17m, Electro House, Hip Hop, Trap" name="description"/>
#   <meta content="2018-09-03T14:56:22+00:00" name="dcterms.created"/>
#   <meta content="2018-09-06" name="dcterms.modified"/>
#   <meta content="JVy3T5_0ZHYNpQmKAdlCE0XF7NDHVCFiOqgcnwP3-dQ" name="google-site-verification"/>
#   <meta content="Lxe3yG4rsMFA8d_yvzcEB_bNmjQyrSeusxHfbm_IBFs" name="google-site-verification"/>
#   <meta content="102282303182342" property="fb:page_id"/>
#   <meta content="1001Tracklists" property="og:site_name"/>
#   <meta content="https://www.1001tracklists.com/tracklist/cbzj0gt/diplo-made-in-america-festival-united-states-2018-09-02.html" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="@1001tracklists" name="twitter:site"/>
#   <meta content="Diplo @ Made In America Festival, United States 2018-09-02" property="og:title"/>
#   <meta content="Diplo @ Made In America Festival, United States 2018-09-02, 122 tracks, 1h17m, Electro House, Hip Hop, Trap" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://i1.sndcdn.com/avatars-000269600255-2fbcze-t300x300.jpg" property="og:image"/>
#   <meta content="300" property="og:image:width"/>
#   <meta content="300" property="og:image:height"/>
#   <meta content="EAD0C6375970330648064F83803ECD57" name="msvalidate.01"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="2 weeks" name="revisit-after"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="#51ABE0" name="theme-color"/>
#   <link href="/images/static/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/static/favicon.png" rel="icon" sizes="16x16"/>
#   <link href="/images/static/favicon32.png" rel="icon" sizes="32x32"/>
#   <link href="/images/static/logo_128.png" rel="icon" sizes="128x128"/>
#   <link href="/images/static/logo_192.png" rel="icon" sizes="192x192"/>
#   <link href="/images/static/logo_256.png" rel="icon" sizes="256x256"/>
#   <link href="/images/static/logo_180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/images/static/logo_152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/images/static/logo_144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/images/static/logo_120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/images/static/logo_114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/images/static/logo_76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/images/static/logo_72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/images/static/logo_60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/images/static/logo_57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <meta content="/images/static/logo_70.png" name="msapplication-square70x70logo"/>
#   <meta content="/images/static/logo_150.png" name="msapplication-square150x150logo"/>
#   <meta content="/images/static/logo_310.png" name="msapplication-square310x310logo"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
#   <style type="text/css">
#    html { height: 100%; } body { min-width: 320px; height:100%; margin:0; text-align:left; font-family: "Helvetica Neue",Helvetica,Arial,sans-serif;line-height: 1.42857; } div.main, #topNavi { max-width: 1440px; margin: 0 auto;} div.main { background-color: white; min-height: 100%;} #fixTop { background-color: #f8f8f8; border-bottom:1px solid #e7e7e7; width:100%; z-index:4; text-align: center; } .fixed { position: fixed; top:0; } .fixed + div.main { padding-top: 49px; } .fixFont, input, button.small, .userNaviMenu { font-size: 14px !important; } button, body, input { color:#333; } #topLogo { margin: 0 auto; height: 62px; display:block; cursor: pointer;} #naviLogo img { margin-top:-25px; } a, .blueTxt, .fa-apple { text-decoration:none; color: #0066C0; } .tlTbl a:visited { color:#03377A !important; } span.tlLink { margin-right:5px; float:left; font-size: 120%;} h1#pageTitle { font-size:120%; margin: 10px 0 0 0; line-height: 1.5;} iframe { border: 0 none; overflow:hidden; } .titleSlogan { letter-spacing: 0.5px; text-transform: uppercase;} .bannerFP { padding: 0px !important;} .nohover:hover, a.fa:hover { text-decoration:none; } ul:not(.bs) { list-style-type:none; margin:0; padding:0;} .fa-32 { font-size: 32px !important; } .fa-30 { font-size: 30px !important; } .fa-24 { font-size: 24px !important; } .fa-20 { font-size: 20px !important; } .fa-16 { font-size: 16px !important; } .fa-12 { font-size: 12px !important; } .fa-m2 { margin-top: 2px !important; } th { text-align: center; } del { color:#E86666; } span.input { background-color: #EEE; border: 1px solid #DDD; padding: 2px;} .navi { font-size: 120%; margin-top:10px;} #contentDiv { height:100%; top:0px; left:0; position: relative; margin:0 5px; padding: 0;} .left { text-align: left; } .center { text-align:center; } .right { text-align:right; } .noPad { padding:0 !important; } .full { width:100% !important; margin:0 auto; } #main { position: absolute; top:0; left:0; margin: 0px; width:100%; background-color: white; padding:0;} .mainContentDiv { position:relative; top:0; left:0; margin:0px; width:100%; height: 100%; } #middleDiv { position:relative; top:0; left:0; margin:0px; width:100%; } .leftSide { position:absolute; left:0; top:0; padding:0; width:100%; z-index:2; } .rightSide { position:absolute; right:0; top:0; width:0; display: none; } .secondRow, .tab-bar { background-color:#F8F8F8; } .iBlock, .inlineBlock { display:inline-block; } .userNaviTable, .dashNaviTable { background-color:#F8F8F8; border:1px solid #E7E7E7; width: 100%; border-radius: 5px; border-spacing: 3px; border-collapse: separate;} .userNavi, .dashNavi { padding:0 10px; cursor: pointer; color:#222; } .userNavi { font-size: 28px; } .userNavi, .dashNavi:not(:first-child) { border-left: 2px #E7E7E7 solid; } .dashNavi { float:left; text-align: center; } .dashNavi div { margin: 0 auto; } div.side { margin-bottom:4px; overflow: hidden; } .floatL { float:left; } .floatR { float:right; } .clearL { clear:left;} .clearR { clear:right;} .unvisible { display:none !important;} .unvisibleU { display:none !important;} .beta { display: none; } .small { font-size:80%; letter-spacing: -1px;} .img16adLeft { width: 300px; height:auto; padding:5px 0;} div.naviTop { display: none; font-size: 90%; } div.tlBrowse { opacity:.80; float:left; margin-right:5px; } .dColor { background-color: #D9EDF7 !important; } table.middle { width:100%; border-collapse:collapse; border-spacing:0px; padding:0; margin-left:auto; margin-right:auto; } table.default { width:100%; border:1px solid #DDD; border-collapse:collapse; border-spacing:0px; margin:0 auto; padding:0; text-align: center; } table.default tr { border-top:1px solid #DDD; } table.default td { vertical-align:middle; padding:3px 1px;} table.default th { background-color:#D9EDF7; vertical-align:middle; padding: 5px 1px; } table.detail { width:auto; text-align:left; margin:0 auto; margin-bottom:10px; vertical-align:bottom; } table.tlBrowse tr.yearRow th { background-color:#D9EDF7; line-height: ...
#   </style>
#   <link href="/css/style_v42.css" rel="stylesheet" type="text/css"/>
#   <script>
#    var wb = window.wb || (window.wb = {}); wb.q || (wb.q = []);
#   </script>
#   <script async="" src="https://dtpy2njj1v50x.cloudfront.net/">
#   </script>
#   <script>
#    function adbChk() { var adChk = document.getElementById('adframe'); if (adChk) { if ( (adChk.currentStyle && adChk.currentStyle.display == 'none') || getComputedStyle(adChk, null).display == 'none') { return true; } } return false; }
#   </script>
#   <script>
#    var googletag = googletag || {}; googletag.cmd = googletag.cmd || [];
#   </script>
#   <script src="/js/sws-hb-180503.js">
#   </script>
#   <script async="" src="https://widget.mixcloud.com/media/js/widgetApi.js">
#   </script>
#   <script async="" crossorigin="anonymous" id="js_jquery.min.js" src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js">
#   </script>
#   <script>
#    window.ga=window.ga||function() { (ga.q=ga.q||[]).push(arguments) };ga.l=+new Date; ga('create', 'UA-23060751-1', 'auto'); ga('set', 'anonymizeIp', true); var gaLnkTrk = function(category, action, label, url) { ga('send', 'event', category, action, label, { 'transport': 'beacon', 'hitCallback': function() { window.open(url, '_blank'); } }); }; var gaEvtTrk = function(category, action, label) { ga('send', 'event', category, action, label); };
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    var jsbuffer = []; var iFrameBuffer = []; var audioPlayers = new Array(); var ytPlayers = new Array(); var serverTime = new Date(1541654203*1000); var scriptDomain = ''; var _gaq = [];
#   </script>
#   <style id="antiClickjack">
#    body { display:none !important; }
#   </style>
#   <script>
#    if (self === top) { var antiClickjack = document.getElementById("antiClickjack"); antiClickjack.parentNode.removeChild(antiClickjack); } else { top.location = self.location; }
#   </script>
#  </head>
#  <body>
#   <meta content="Diplo @ Made In America Festival, United States 2018-09-02" itemprop="name"/>
#   <meta content="Mato6" itemprop="author"/>
#   <meta content="2018-09-03T14:56:22+00:00" itemprop="datePublished"/>
#   <meta content="2018-09-06T02:52:46+00:00" itemprop="dateModified"/>
#   <meta content="tracklist" itemprop="genre"/>
#   <meta content="Tracklist / Playlist for Diplo @ Made In America Festival, United States 2018-09-02, 122 tracks, 1h17m, Electro House, Hip Hop, Trap" itemprop="description"/>
#   <meta content="Diplo @ Made In America Festival 2018-09-02" itemprop="headline"/>
#   <span class="hidden" itemprop="image" itemscope="" itemtype="http://schema.org/ImageObject">
#    <meta content="https://i1.sndcdn.com/avatars-000269600255-2fbcze-t300x300.jpg" itemprop="url"/>
#    <meta content="300" itemprop="width"/>
#    <meta content="300" itemprop="height"/>
#   </span>
#   <meta itemid="https://www.1001tracklists.com/tracklist/cbzj0gt/diplo-made-in-america-festival-united-states-2018-09-02.html" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"/>
#   <span class="hidden" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#    <meta content="1001Tracklists" itemprop="name"/>
#    <meta content="https://www.1001tracklists.com" itemprop="url"/>
#    <span class="hidden" itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#     <meta content="https://www.1001tracklists.com/images/static/logo_150.png" itemprop="url"/>
#    </span>
#   </span>
#   <ul class="bs dropdown-menu" id="exploreNaviMenu">
#    <li class="h32">
#     <a href="/stories/index.html">
#      Stories
#     </a>
#    </li>
#    <li class="h32">
#     <a href="/groups/index.html">
#      Tracklist Groups
#     </a>
#    </li>
#    <li class="divider" role="separator">
#    </li>
#    <li class="h32">
#     <a data-target="#catHotShowsModal" data-toggle="modal" href="#">
#      Hot Shows
#     </a>
#    </li>
#    <li class="h32">
#     <a data-target="#catHotEventsModal" data-toggle="modal" href="#">
#      Hot Events
#     </a>
#    </li>
#    <li class="h32">
#     <a href="/charts/weekly/index.html">
#      Charts
#     </a>
#    </li>
#    <li class="h32">
#     <a href="/specials/premium_audio_livesets/index.html">
#      Premium Audio Livesets
#     </a>
#    </li>
#    <li class="divider" role="separator">
#    </li>
#    <li class="h32">
#     <a data-target="#catStylesModal" data-toggle="modal" href="#">
#      Styles
#     </a>
#    </li>
#    <li class="h32">
#     <a data-target="#catYearsModal" data-toggle="modal" href="#">
#      Years
#     </a>
#    </li>
#    <li class="divider" role="separator">
#    </li>
#    <li>
#     <a class="action nohover" href="#" onclick="new MessageBox(this, { type: 'fbMsg', headText: 'Contact Us', submitButtonTxt: 'Close', submitButtonIcon: 'remove', isDanger: true} ).show();">
#      <i class="fa fa-envelope blueTxt fa-24 mAlign" id="info_message" title="send message">
#      </i>
#      Contact
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="https://www.facebook.com/1001tracklists" rel="noopener noreferrer" target="_blank" title="facebook">
#      <i class="fa fa-facebook-official fa-24 mAlign">
#      </i>
#      Facebook
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="https://www.twitter.com/1001tracklists" rel="noopener noreferrer" target="_blank" title="twitter">
#      <i class="fa fa-twitter-square fa-24 mAlign">
#      </i>
#      Twitter
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="https://soundcloud.com/1001tracklists/" rel="noopener noreferrer" target="_blank" title="soundcloud">
#      <i class="fa fa-soundcloud fa-16 mAlign">
#      </i>
#      Soundcloud
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="https://open.spotify.com/user/1001tracklists" rel="noopener noreferrer" target="_blank" title="spotify">
#      <i class="fa fa-spotify fa-24 mAlign">
#      </i>
#      Spotify
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="http://www.1001tracklists.com/rss/tracklists.xml" rel="noopener noreferrer" target="_blank" title="rss">
#      <i class="fa fa-rss-square fa-24 mAlign">
#      </i>
#      RSS Feed
#     </a>
#    </li>
#    <li>
#     <a class="h32" href="https://www.instagram.com/1001tracklistsofficial/" rel="noopener noreferrer" target="_blank" title="instagram">
#      <i class="fa fa-instagram fa-24 mAlign">
#      </i>
#      Instagram
#     </a>
#    </li>
#    <li class="divider" role="separator">
#    </li>
#    <li>
#     <a href="http://shop.spreadshirt.de/1001tracklists/" rel="noopener noreferrer" target="_blank">
#      <i class="fa fa-shopping-cart blueTxt fa-24 mAlign">
#      </i>
#      <i class="fa fa-euro blueTxt fa-16 mAlign">
#      </i>
#      Shop Europe
#     </a>
#    </li>
#    <li>
#     <a href="http://shop.spreadshirt.com/1001tracklists/" rel="noopener noreferrer" target="_blank">
#      <i class="fa fa-shopping-cart blueTxt fa-24 mAlign">
#      </i>
#      <i class="fa fa-dollar blueTxt fa-16 mAlign">
#      </i>
#      Shop Rest Of World
#     </a>
#    </li>
#    <li class="divider" role="separator">
#    </li>
#    <li class="h32">
#     <a href="/info/whatsnew.html">
#      What's New
#     </a>
#    </li>
#   </ul>
#   <div id="fixTop">
#    <nav id="topNavi">
#     <div id="navBarTop">
#      <a class="nohover spR" href="/" id="naviLogo" title="1001tracklists home">
#       <img alt="1001.tl" height="49" src="/images/static/1001logo_xs.png" width="56"/>
#      </a>
#      <div class="navIcons" id="navIconsL">
#       <a class="nohover navIcon floatR" href="#" id="searchButton" onclick="createSearchAc();" title="search">
#        <i class="fa fa-search blueTxt ">
#        </i>
#       </a>
#       <ul class="floatR" id="navBarTopRight">
#        <li class="dropdown">
#         <span aria-expanded="false" aria-haspopup="true" class="dropdown-toggle blueTxt navIcon" data-toggle="dropdown" id="exploreNavi" onclick="new UserMenu(this);" role="button">
#          Explore
#          <span class="caret">
#          </span>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div class="searchBar fixFont" id="searchBar">
#       <form accept-charset="utf-8" action="/search/result.php" id="searchForm" method="post" name="searchForm">
#        <div class="input-group">
#         <div class="input-group-btn" id="searchBarIconL">
#          <div class="btn btn-default btn-primary">
#           <i class="fa fa-search">
#           </i>
#          </div>
#         </div>
#         <div class="input-group-btn search-panel fixFont" id="searchBarSelect">
#          <select class="searchFieldSelect center" id="search_selection" name="search_selection" title="select search object">
#           <option value="9">
#            Tracklists
#           </option>
#           <option value="2">
#            Tracks
#           </option>
#           <option value="8">
#            DJs
#           </option>
#           <option value="11">
#            Sources
#           </option>
#           <option value="7">
#            Labels
#           </option>
#           <option value="12">
#            Stories
#           </option>
#          </select>
#         </div>
#         <input autocomplete="off" class="form-control" id="main_search" name="main_search" onblur="leaveSearch();" onclick="createSearchAc();" placeholder="Search" title="Search" type="text" value=""/>
#         <div class="input-group-btn">
#          <button class="btn btn-default btn-primary" id="searchBtn" onclick="return searchCheck(this);" type="submit">
#           Search
#          </button>
#         </div>
#        </div>
#        <div class="redTxt iBlock infoImgDiv" id="search_info" style="">
#         <i class="fa fa-info fa-2x redTxt">
#         </i>
#         <span id="search_info_msg">
#          minimum 5 chars required for search!
#         </span>
#        </div>
#       </form>
#      </div>
#     </div>
#    </nav>
#   </div>
#   <div class="main" id="contentRoot">
#    <div id="adframe">
#    </div>
#    <div class="top" id="top">
#     <div class="center" id="topExNet">
#      <div class="exNet adDFP img15ad" id="div-gpt-top_lb">
#       <div id="div-swshb-top_leaderboard-1-0">
#       </div>
#      </div>
#     </div>
#     <div id="topArtwork">
#     </div>
#     <h1 class="topContent " id="pageTitle">
#      Diplo @ Made In America Festival, United States 2018-09-02
#     </h1>
#     <nav class="navi topContent " id="pageNavi">
#      <a href="/">
#       Home
#      </a>
#      <i class="fa fa-caret-right fa-lg blueTxt">
#      </i>
#      <span>
#       Tracklists
#      </span>
#      <i class="fa fa-caret-right fa-lg blueTxt">
#      </i>
#      <span>
#       <a class="" href="/dj/diplo/index.html">
#        Diplo
#       </a>
#      </span>
#      <i class="fa fa-caret-right fa-lg blueTxt">
#      </i>
#      <span>
#       <a href="/source/hw1zvm/made-in-america-festival/index.html">
#        Made In America Festival
#       </a>
#      </span>
#     </nav>
#     <div class="topContent " id="headInfoLine">
#     </div>
#    </div>
#    <ul class="nav nav-tabs" id="toogleView">
#     <li class="active" data-toogle="main" onclick="toogleSideView(this);" role="presentation">
#      <a>
#       Tracklist
#      </a>
#     </li>
#     <li data-toogle="left" onclick="toogleSideView(this);" role="presentation">
#      <a>
#       Additional Info
#      </a>
#     </li>
#    </ul>
#    <div id="contentDiv">
#     <form action="/edit/tracklist.php" id="frmEditTracklist" method="post" name="frmEditTracklist" onsubmit="window.onbeforeunload = null;">
#      <input name="id_tracklist" type="hidden" value="179735"/>
#      <input name="tl_pos_count" type="hidden" value="122"/>
#      <input name="tl_lastmodified" type="hidden" value="2018-09-06 02:52:46"/>
#      <div class="leftSide hidden" id="leftDiv">
#       <div class="center" id="leftExNet">
#        <div class="exNet adDFP img15ad" id="div-gpt-left_rec">
#         <div id="div-swshb-sidebar_1_left-1-0">
#         </div>
#        </div>
#       </div>
#       <div class="leftContent" id="leftContent">
#        <div class="center" id="artworkLeft">
#        </div>
#        <div class="side">
#         <table class="default nohover">
#          <tr>
#           <th colspan="2">
#            General Information
#           </th>
#          </tr>
#          <tr class=" ">
#           <td>
#            <span title="tracklist recording date">
#             TL date
#            </span>
#           </td>
#           <td>
#            Sun, Sep 2 2018
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            posted by
#           </td>
#           <td>
#            <a href="/user/mato6/index.html" target="_blank" title="open user page">
#             Mato6
#            </a>
#            (50.3k)
#           </td>
#          </tr>
#          <tr class=" ">
#           <td>
#            posted at
#           </td>
#           <td>
#            <time datetime="2018-09-03 14:56:22" itemprop="datePublished">
#             Mon, Sep 3, 2018 14:56:22 GMT
#            </time>
#            <br/>
#            <span class="dateAgo">
#             <i class="fa fa-plus-circle blueTxt fa-16">
#             </i>
#             <i data-date="1535986582">
#             </i>
#            </span>
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            last update
#           </td>
#           <td>
#            <time datetime="2018-09-06 02:52:46" itemprop="dateModified">
#             Thu, Sep 6, 2018 02:52:46 GMT
#            </time>
#            <br/>
#            <span class="dateAgo">
#             <i class="fa fa-plus-circle blueTxt fa-16">
#             </i>
#             <i data-date="1536202366">
#             </i>
#            </span>
#           </td>
#          </tr>
#          <tr class=" ">
#           <td>
#            views
#           </td>
#           <td>
#            <meta content="UserPageVisits:4767" itemprop="interactionCount"/>
#            4,767
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            likes
#           </td>
#           <td>
#            <meta content="UserLikes:6" itemprop="interactionCount"/>
#            6
#           </td>
#          </tr>
#          <tr class=" ">
#           <td>
#            IDed
#           </td>
#           <td>
#            <span class="greenTxt">
#             all
#            </span>
#            / 71
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            short url
#           </td>
#           <td>
#            <a href="http://1001.tl/cbzj0gt">
#             1001.tl/cbzj0gt
#            </a>
#           </td>
#          </tr>
#         </table>
#         <table class="default nohover">
#          <tr>
#           <th>
#            Tracklist Musicstyle(s)
#           </th>
#          </tr>
#          <tr>
#           <td id="tl_music_styles">
#            Electro House, Hip Hop, Trap
#           </td>
#          </tr>
#         </table>
#         <a class="list-group-item headBG" data-parent="#aMenuTRACKLIST179735" data-toggle="collapse" href="#tls7TRACKLIST179735" onclick="new StatisticUpdater(this, { mode: '7', destTable: 'tlsTbl7TRACKLIST179735', idObject: 1, idItem: 179735, oneLoad: true } ).update();" role="button">
#          <i class="fa fa-caret-right fa-lg">
#          </i>
#          Related Tracklists
#         </a>
#         <div class="collapse aMenuItem " id="tls7TRACKLIST179735" role="tabpanel">
#          <table class="default tlTbl" id="tlsTbl7TRACKLIST179735">
#          </table>
#         </div>
#         <table class="default">
#          <tr>
#           <th class="h32" colspan="3">
#            <i class="fa fa-32 fa-calendar blueTxt mAlign floatL">
#            </i>
#            Favoritings
#           </th>
#          </tr>
#          <tr>
#           <td>
#            2 users + 1 guest
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div class="side">
#         <table class="default sideTop">
#          <tr>
#           <th>
#            <a class="" href="/dj/diplo/index.html">
#             Diplo
#            </a>
#            <img alt="United States" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/us.png" title="Home Country United States" width="32"/>
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <div>
#             <a class="h32 nohover nohover" href="https://www.beatport.com/artist/diplo/16134" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Beatport link">
#              <i class="fa fa-shopping-cart blueTxt fa-24 mAlign">
#              </i>
#              Beatport
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://itunes.apple.com/artist/4527097" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Apple Music link">
#              <i class="fa fa-apple fa-24 mAlign">
#              </i>
#              Apple Music
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://soundcloud.com/diplo" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="SoundCloud link">
#              <i class="fa fa-soundcloud fa-24 mAlign">
#              </i>
#              SoundCloud
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://www.youtube.com/channel/UCKp7UVaoVuiW1qtyPLPVFMQ" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="YouTube link">
#              <i class="fa fa-youtube-play fa-24 mAlign">
#              </i>
#              YouTube
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://play.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Spotify link">
#              <i class="fa fa-spotify fa-24 mAlign">
#              </i>
#              Spotify
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://www.facebook.com/diplo" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Facebook link">
#              <i class="fa fa-facebook-official fa-24 mAlign">
#              </i>
#              Facebook
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="https://twitter.com/DIPLO" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Twitter link">
#              <i class="fa fa-twitter-square fa-24 mAlign">
#              </i>
#              Twitter
#             </a>
#            </div>
#            <div>
#             <a class="h32 nohover nohover" href="http://www.maddecent.com" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Website link">
#              <i class="fa fa-globe fa-24 mAlign">
#              </i>
#              Website
#             </a>
#            </div>
#            <a class="iBlock mAlign h32 nohover" href="https://www.google.com/search?q=Diplo" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="search the web via google">
#             <i class=" fa fa-24 fa-google mAlign ">
#             </i>
#             Google-Search
#            </a>
#           </td>
#          </tr>
#         </table>
#         <table class="default">
#          <tr>
#           <th>
#            Short Link
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <a href="http://1001.tl/m3qwhl">
#             1001.tl/m3qwhl
#            </a>
#           </td>
#          </tr>
#         </table>
#         <table class="default">
#          <tr>
#           <th>
#            Member Of
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <a class="" href="/dj/majorlazer/index.html">
#             Major Lazer
#            </a>
#            <img alt="United States" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/us.png" title="United States" width="32"/>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="" href="/dj/jacku/index.html">
#             Jack Ü
#            </a>
#            <img alt="United States" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/us.png" title="United States" width="32"/>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="" href="/dj/silkcity/index.html">
#             Silk City
#            </a>
#            <img alt="United States" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/us.png" title="United States" width="32"/>
#            <img alt="United Kingdom" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/uk.png" title="United Kingdom" width="32"/>
#           </td>
#          </tr>
#         </table>
#         <table class="default">
#          <tr>
#           <th>
#            Hosted Shows / Podcasts
#           </th>
#          </tr>
#          <tr class="">
#           <td>
#            <a href="/source/r0bxpm/blow-your-head/index.html">
#             Blow Your Head
#            </a>
#            on
#            <a href="/source/dkky7v/siriusxm/index.html">
#             SiriusXM
#            </a>
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            <a href="/source/k2gffv/diplo-and-friends/index.html">
#             Diplo &amp; Friends
#            </a>
#            on
#            <a href="/source/vtbhw3/bbc-radio-1xtra/index.html">
#             BBC Radio 1Xtra
#            </a>
#           </td>
#          </tr>
#          <tr class="">
#           <td>
#            <a href="/source/vuhhh3/diplo-and-friends-evolution-radio-show/index.html">
#             Diplo &amp; Friends Evolution Radio Show
#            </a>
#            on
#            <a href="/source/vt9gpm/iheartradio/index.html">
#             iHeartRadio
#            </a>
#           </td>
#          </tr>
#          <tr class="secondRow">
#           <td>
#            <a href="/source/93shlm/records-on-records/index.html">
#             Records On Records
#            </a>
#            on
#            <a href="/source/dkky7v/siriusxm/index.html">
#             SiriusXM
#            </a>
#           </td>
#          </tr>
#         </table>
#         <table class="default">
#          <tr>
#           <th>
#            Owned/Involved Labels
#           </th>
#          </tr>
#          <tr class="">
#           <td>
#            <a class="" href="/label/qf0hnr/mad-decent/index.html" title="Mad Decent">
#             Mad Decent
#            </a>
#           </td>
#          </tr>
#         </table>
#         <table class="default center">
#          <tr>
#           <th>
#            Producer Chart Ranks
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <a href="/charts/year/2018/producer.html">
#             2018
#            </a>
#            #8
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a href="/charts/year/2017/producer.html">
#             2017
#            </a>
#            #4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a href="/charts/year/2016/producer.html">
#             2016
#            </a>
#            #4
#           </td>
#          </tr>
#         </table>
#         <div class="aMenu" id="aMenuDJ1430">
#          <a class="list-group-item " data-parent="#aMenuDJ1430" data-toggle="collapse" href="#tls4DJ1430" onclick="new StatisticUpdater(this, { mode: '4', destTable: 'tlsTbl4DJ1430', idObject: 2, idItem: 1430, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Last Tracklists
#          </a>
#          <div class="collapse aMenuItem " id="tls4DJ1430" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl4DJ1430">
#           </table>
#          </div>
#          <a class="list-group-item " data-parent="#aMenuDJ1430" data-toggle="collapse" href="#tls5DJ1430" onclick="new StatisticUpdater(this, { mode: '5', destTable: 'tlsTbl5DJ1430', idObject: 2, idItem: 1430, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Most Liked Tracklists
#          </a>
#          <div class="collapse aMenuItem " id="tls5DJ1430" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl5DJ1430">
#           </table>
#          </div>
#          <a class="list-group-item " data-parent="#aMenuDJ1430" data-toggle="collapse" href="#tls8DJ1430" onclick="new StatisticUpdater(this, { mode: '8', destTable: 'tlsTbl8DJ1430', idObject: 2, idItem: 1430, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Most Viewed Tracklists
#          </a>
#          <div class="collapse aMenuItem " id="tls8DJ1430" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl8DJ1430">
#           </table>
#          </div>
#          <a class="list-group-item " data-parent="#aMenuDJ1430" data-toggle="collapse" href="#tls3DJ1430" onclick="new StatisticUpdater(this, { mode: '3', destTable: 'tlsTbl3DJ1430', idObject: 2, idItem: 1430, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Most Watched IDs
#          </a>
#          <div class="collapse aMenuItem " id="tls3DJ1430" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl3DJ1430">
#           </table>
#          </div>
#          <a class="list-group-item " data-parent="#aMenuARTIST3615" data-toggle="collapse" href="#tls6ARTIST3615" onclick="new StatisticUpdater(this, { mode: '6', destTable: 'tlsTbl6ARTIST3615', idObject: 4, idItem: 3615, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Last Tracks
#          </a>
#          <div class="collapse aMenuItem " id="tls6ARTIST3615" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl6ARTIST3615">
#           </table>
#           <div class="border noTopBorder h32">
#            <i class="blueTxt fa fa-external-link fa-24 mAlign">
#            </i>
#            <a class="" href="/artist/hwwndw/diplo/index.html">
#             Show All Tracks
#            </a>
#           </div>
#          </div>
#         </div>
#         <table class="default">
#          <tr>
#           <th>
#            <div class="sprite sprite-dj floatL">
#             <div class="sprite sprite-fav_overlay">
#             </div>
#            </div>
#            Favoritings
#           </th>
#          </tr>
#          <tr>
#           <td>
#            164 users + 80 guests
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div class="side">
#         <table class="default sideTop">
#          <tr>
#           <th>
#            <a href="/source/hw1zvm/made-in-america-festival/index.html">
#             Made In America Festival
#            </a>
#            <img alt="United States" class=" mAlign" height="32" src="//cdn.1001.tl/images/flags/us.png" title="United States" width="32"/>
#           </th>
#          </tr>
#          <tr>
#           <td>
#            Open Air / Festival
#            <div>
#             <a class="h32 nohover nohover" href="http://www.madeinamericafest.com" onclick="" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="Website link">
#              <i class="fa fa-globe fa-24 mAlign">
#              </i>
#              Website
#             </a>
#            </div>
#            <div>
#             <a class="iBlock mAlign h32 nohover" href="https://www.google.com/search?q=Made+In+America+Festival" rel="noopener noreferrer" style="white-space: nowrap;" target="_blank" title="search the web via google">
#              <i class=" fa fa-24 fa-google mAlign ">
#              </i>
#              Google-Search
#             </a>
#            </div>
#           </td>
#          </tr>
#         </table>
#         <table class="default">
#          <tr>
#           <th>
#            Short Link
#           </th>
#          </tr>
#          <tr>
#           <td>
#            <a href="http://1001.tl/hw1zvm">
#             1001.tl/hw1zvm
#            </a>
#           </td>
#          </tr>
#         </table>
#         <div class="aMenu" id="aMenuSource2742">
#          <a class="list-group-item " data-parent="#aMenuSOURCE2742" data-toggle="collapse" href="#tls4SOURCE2742" onclick="new StatisticUpdater(this, { mode: '4', destTable: 'tlsTbl4SOURCE2742', idObject: 3, idItem: 2742, oneLoad: true } ).update();" role="button">
#           <i class="fa fa-caret-right fa-lg">
#           </i>
#           Last Tracklists
#          </a>
#          <div class="collapse aMenuItem " id="tls4SOURCE2742" role="tabpanel">
#           <table class="default tlTbl" id="tlsTbl4SOURCE2742">
#           </table>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <main id="main">
#       <div id="mediaItemsTop">
#        <div id="mediaItems">
#         <div class="border">
#          <div class="tab-bar-head h24 left headBG bottomBorder bold">
#           <i class="fa fa-24 fa-download blueTxt mAlign">
#           </i>
#           Tracklist Media Links
#          </div>
#          <ul class="tab-bar bottomBorder">
#           <li class="tab-btn action" onclick="openTab(this, 'mediaTab', 'mediaTab16')">
#            <span class="tab-btn-active h24">
#             <i class="fa fa-24 fa-mixcloud mAlign">
#             </i>
#             MixCloud
#            </span>
#           </li>
#           <li class="tab-btn action noUser" onclick="new MediaSubmitter(this, 'add_media', 'dl', { idObject: '1', idItem: '179735', idTL: '179735' });" title="add a media link for this tracklist">
#            <span class="h24">
#             <i class="fa fa-24 fa-plus-circle mAlign blueTxt">
#             </i>
#             Add
#            </span>
#           </li>
#          </ul>
#          <div class="mediaTabItem " id="mediaTab16">
#           <ul class="tab-bar bottomBorder">
#            <li class="tab-btn" id="mediaLinkBtn878274" onclick="openTab(this, 'mediaTab16', 'mediaLink878274')">
#             <span class="tab-btn-active">
#              Player 1 [01:17:13]
#             </span>
#            </li>
#           </ul>
#           <div class="mediaLink " data-idmedia="878274" data-idsource="16" id="mediaLink878274">
#            <div class="mediaDiv center" id="mediaLink878274_player">
#             <script>
#              iFrameBuffer.push(['mediaLink878274_player', '<div itemprop="audio" style="margin:5px;"><iframe height="300" class="mediaPlayer mcWidget1 full" sandbox="allow-scripts allow-same-origin" id="mcWidget_878274" src="https://www.mixcloud.com/widget/iframe/?feed=https%3A%2F%2Fwww.mixcloud.com%2Fwnmfest_official%2Fdiplo-made-in-america-festival-02092018%2F&amp;hide_cover=1&amp;light=1"></iframe><div style="clear:both;"></div></div>' , function() { audioPlayers[audioPlayers.length] = new AudioPlayerMC("mcWidget_878274", { idPlayer: "878274", source: "wnmfest_official", duration: "4633" });} ]);
#             </script>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="mainContentDiv" id="mainContentDiv">
#        <div class="middleDiv" id="middleDiv">
#         <table class="middle center" id="middleTbl">
#          <tr>
#           <td>
#            <div itemscope="" itemtype="http://schema.org/MusicPlaylist">
#             <meta content="Diplo @ Made In America Festival, United States 2018-09-02" itemprop="name"/>
#             <meta content="2018-09-02" itemprop="datePublished"/>
#             <meta content="122" itemprop="numTracks"/>
#             <meta content="Electro House" itemprop="genre"/>
#             <meta content="Hip Hop" itemprop="genre"/>
#             <meta content="Trap" itemprop="genre"/>
#             <meta content="Diplo" itemprop="author"/>
#             <div class="soundControl" id="playerWidget" style="display:none;" title="sound player control">
#              <div class="playerWidgetFields" id="playerWidgetFields">
#               <div id="playerWidgetIcon" onclick="$('#playerWidget').hide();" title="hide player">
#               </div>
#               <div id="playerWidgetCurrentTime">
#               </div>
#               <div id="playerWidgetButtons">
#                <div class="fa fa-play fa-32 blueTxt actionIcon" id="playerWidgetPause" onclick="audioPlayerRunning.toggle(true);" title="toggle sound">
#                </div>
#                <div class="actionIcon" id="playerWidgetVolume" style="display: none; width: 48px;" title="change player volume">
#                 <div class="fa fa-volume-up fa-32 blueTxt" id="playerWidgetVolumeMute" onclick="audioPlayerRunning.mute();" title="mute sound">
#                 </div>
#                 <div class="fa fa-volume-off fa-32 redTxt" id="playerWidgetVolumeUnmute" onclick="audioPlayerRunning.unmute();" style="display:none;" title="unmute sound">
#                 </div>
#                 <span id="playerWidgetVolumeLevel" title="change volume level">
#                  <span class="playerWidgetVolumeLevel" id="playerWidgetVolume10" onclick="audioPlayerRunning.setVolume(100);" style="top: 0px;">
#                  </span>
#                  <span class="playerWidgetVolumeLevel" id="playerWidgetVolume8" onclick="audioPlayerRunning.setVolume(80);" style="top: 8px;">
#                  </span>
#                  <span class="playerWidgetVolumeLevel" id="playerWidgetVolume5" onclick="audioPlayerRunning.setVolume(50);" style="top: 16px;">
#                  </span>
#                  <span class="playerWidgetVolumeLevel" id="playerWidgetVolume2" onclick="audioPlayerRunning.setVolume(20);" style="top: 24px;">
#                  </span>
#                 </span>
#                </div>
#               </div>
#               <div id="playerWidgetInfo">
#                <div id="playerWidgetTitle">
#                </div>
#                <div id="playerWidgetDuration">
#                </div>
#                <div id="playerWidgetWarn">
#                </div>
#                <div id="playerWidgetStatus">
#                </div>
#               </div>
#              </div>
#              <div class="playerWidgetWaveForm" id="playerWidgetWaveFormBG" style="display: none;">
#               <div class="playerWidgetWaveFormFull">
#                <div class="playerWidgetWaveFormProgress" id="playerWidgetWaveFormProgress">
#                </div>
#               </div>
#              </div>
#              <div class="waveFormSeekToIndicator" id="waveFormSeekToIndicator" style="display:none;">
#              </div>
#              <div class="waveFormSeekToCueDiv" id="waveFormSeekToCueDiv" style="display:none;">
#              </div>
#              <div class="playerWidgetWaveForm" id="playerWidgetWaveForm">
#              </div>
#              <div class="playerWidgetMessage marquee">
#               <span id="playerWidgetMessage">
#               </span>
#              </div>
#             </div>
#             <script>
#              jsbuffer.push(['ready', function() { cueValues = []; cueValueData = []; cueValuesPlayerData = []; cueValuesEntry = {}; cueValuesEntry.seconds = 0; cueValuesEntry.number = '1'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp0_content'; cueValueData.push(cueValuesEntry); cueValues.push(0); cueValuesEntry = {}; cueValuesEntry.seconds = 122; cueValuesEntry.number = '2'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp1_content'; cueValueData.push(cueValuesEntry); cueValues.push(122); cueValuesEntry = {}; cueValuesEntry.seconds = 180; cueValuesEntry.number = '3'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp3_content'; cueValueData.push(cueValuesEntry); cueValues.push(180); cueValuesEntry = {}; cueValuesEntry.seconds = 223; cueValuesEntry.number = '4'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp7_content'; cueValueData.push(cueValuesEntry); cueValues.push(223); cueValuesEntry = {}; cueValuesEntry.seconds = 310; cueValuesEntry.number = '5'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp11_content'; cueValueData.push(cueValuesEntry); cueValues.push(310); cueValuesEntry = {}; cueValuesEntry.seconds = 375; cueValuesEntry.number = '6'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp12_content'; cueValueData.push(cueValuesEntry); cueValues.push(375); cueValuesEntry = {}; cueValuesEntry.seconds = 480; cueValuesEntry.number = '7'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp15_content'; cueValueData.push(cueValuesEntry); cueValues.push(480); cueValuesEntry = {}; cueValuesEntry.seconds = 533; cueValuesEntry.number = '8'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp16_content'; cueValueData.push(cueValuesEntry); cueValues.push(533); cueValuesEntry = {}; cueValuesEntry.seconds = 585; cueValuesEntry.number = '9'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp18_content'; cueValueData.push(cueValuesEntry); cueValues.push(585); cueValuesEntry = {}; cueValuesEntry.seconds = 610; cueValuesEntry.number = '10'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp21_content'; cueValueData.push(cueValuesEntry); cueValues.push(610); cueValuesEntry = {}; cueValuesEntry.seconds = 696; cueValuesEntry.number = '11'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp22_content'; cueValueData.push(cueValuesEntry); cueValues.push(696); cueValuesEntry = {}; cueValuesEntry.seconds = 745; cueValuesEntry.number = '12'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp24_content'; cueValueData.push(cueValuesEntry); cueValues.push(745); cueValuesEntry = {}; cueValuesEntry.seconds = 798; cueValuesEntry.number = '13'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp29_content'; cueValueData.push(cueValuesEntry); cueValues.push(798); cueValuesEntry = {}; cueValuesEntry.seconds = 930; cueValuesEntry.number = '14'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp31_content'; cueValueData.push(cueValuesEntry); cueValues.push(930); cueValuesEntry = {}; cueValuesEntry.seconds = 960; cueValuesEntry.number = '15'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp32_content'; cueValueData.push(cueValuesEntry); cueValues.push(960); cueValuesEntry = {}; cueValuesEntry.seconds = 1034; cueValuesEntry.number = '16'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp33_content'; cueValueData.push(cueValuesEntry); cueValues.push(1034); cueValuesEntry = {}; cueValuesEntry.seconds = 1120; cueValuesEntry.number = '17'; cueValuesEntry.idPlayer = ''; cueValuesEntry.ids = []; cueValuesEntry.ids[0] = 'tlp37_content' ...
#             </script>
#             <table class="default full tl hover">
#              <colgroup>
#               <col style="width:1.5em;"/>
#               <col style="width:32px;"/>
#               <col/>
#               <col style="width:32px;"/>
#              </colgroup>
#              <tr>
#               <th class="left">
#                #
#               </th>
#               <th>
#               </th>
#               <th class="left">
#                Artist - Title (Remix)
#               </th>
#               <th>
#               </th>
#              </tr>
#              <tr class="tlpTog tlpTog tlpItem trRow1 topBorder" id="tlp_3567265" onclick="rowToggle('tlp', event);">
#               <td class="left" id="tlp0_number_column">
#                <input id="tlp_tracknumber_0" type="hidden" value="1"/>
#                <span class="tlFontLarge" id="tlp0_tracknumber">
#                 <span id="tlp0_tracknumber_value">
#                  01
#                 </span>
#                </span>
#                <div class="cueValueField action" data-mode="hours" id="cue_3567265" onclick="toggleCue();">
#                </div>
#                <input id="tlp_cue_seconds_3567265" type="hidden" value=""/>
#                <div class="tlEdit">
#                 <input class="cueInput tgHid" id="tlp0_cue_string" maxlength="8" onchange="setCueValue(this, { idInput: 'tlp0', idPos: '3567265' } );" onfocus="activateFormField(this, { size: 6 });" placeholder="cue" size="3" title="cue as minutes only or minutes:seconds" type="text" value=""/>
#                 <button class="halfOpacityOver tgHid small" id="tlp_grab_3567265" onclick="grabPositionCue(this, { idInput: 'tlp0', idPos: '3567265', trackNumber: 1, idTrackElement: 'tlptrrow_0' } );" title="grab cue from audio player" type="button">
#                  grab
#                 </button>
#                 <input id="tlp0_id_player_cue" type="hidden" value=""/>
#                 <input id="tlp0_id_player_source" type="hidden" value=""/>
# ...
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2013/index.html">
#          2013
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2012/index.html">
#          2012
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2011/index.html">
#          2011
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2010/index.html">
#          2010
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2009/index.html">
#          2009
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2008/index.html">
#          2008
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2007/index.html">
#          2007
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2006/index.html">
#          2006
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2005/index.html">
#          2005
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2004/index.html">
#          2004
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2003/index.html">
#          2003
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2002/index.html">
#          2002
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2001/index.html">
#          2001
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/year/2000/index.html">
#          &lt;=2000
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-labelledby="catHotEventsTitle" class="modal fade" id="catHotEventsModal" role="dialog" style="display:none;" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title" id="catHotEventsTitle">
#        Hot Events
#       </h4>
#      </div>
#      <div class="modal-body">
#       <ul class="nav nav-pills nav-stacked">
#        <li role="presentation">
#         <a href="/source/3112_umf/index.html" title="Ultra Music Festivals">
#          UMF
#         </a>
#        </li>
#        <li role="presentation">
#         <a href="/source/1145_ultra-music-festival-miami/index.html" title="Ultra Music Festival Miami">
#          UMF Miami
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/2715_ibiza/index.html">
#          Ibiza
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1511_electric-daisy-carnival-edc/index.html" title="Electric Daisy Carneval">
#          EDC
#         </a>
#        </li>
#        <li role="presentation">
#         <a href="/source/3959_electric-daisy-carnival-las-vegas/index.html" title="Electric Daisy Carneval Las Vegas">
#          EDC Vegas
#         </a>
#        </li>
#        <li role="presentation">
#         <a href="/source/3957_electric-daisy-carnival-new-york/index.html" title="Electric Daisy Carnival NYC">
#          EDC NY
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1262_tomorrowland/index.html">
#          Tomorrowland
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1263_nature-one/index.html">
#          Nature One
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1051_mysteryland/index.html">
#          Mysteryland
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1298_electric-zoo-festival/index.html" title="Electric Zoo Festival">
#          ElectricZoo
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/3420_tomorrowworld/index.html">
#          TomorrowWorld
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/2716_creamfields/index.html">
#          Creamfields
#         </a>
#        </li>
#        <li role="presentation">
#         <a class="" href="/source/1024_amsterdam-dance-event-ade/index.html" title="Amsterdam Dance Event">
#          ADE
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    function delAd(ad) { if (ad) { var elToDel = ad; if (elToDel.className.toLowerCase().indexOf('contentlb') > -1) { while (elToDel.parentNode && elToDel.tagName.toLowerCase() != 'tr') { elToDel = elToDel.parentNode; } } var adClass = ' ' + elToDel.className + ' '; if (adClass.indexOf(' adRow ') > -1 || adClass.indexOf(' adDFP ') > -1) { elToDel.parentNode.removeChild(elToDel); } else { } } } function loadGAdCode() { var gads = document.createElement('script'); gads.async = true; gads.type = 'text/javascript'; var useSSL = 'https:' == document.location.protocol; gads.src = (useSSL ? 'https:' : 'http:') + '//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js'; var node = document.getElementsByTagName('script')[0]; node.parentNode.insertBefore(gads, node); } function checkGAdCode() { var scripts = document.getElementsByTagName('script'); for (var i = 0; i < scripts.length; i++) { if (scripts[i].src.indexOf('adsbygoogle') > -1) { return true; } } } var adsenseAdsCount = document.getElementsByClassName('adsenseAd').length; var bLimit = 3; var activeSlots = []; var adsToDel = []; var elem = document.getElementById('div-swshb-top_leaderboard-1-0'); if (elem) { if (window.innerWidth < 350) { if (!checkGAdCode()) { loadGAdCode(); } var gadTop = document.createElement('ins'); gadTop.className = 'adsbygoogle adsenseAd'; gadTop.style = 'display:inline-block;height:60px;' + (window.innerWidth > 475 ? 'width:468px;' : 'width:320px;'); gadTop.dataset.adClient = 'ca-pub-3535786192432916'; gadTop.dataset.adSlot = '1288577930'; gadTop.dataset.adFormat = 'auto'; var gadTopDiv = document.createElement('div'); gadTopDiv.className = 'img15ad exNet'; gadTopDiv.appendChild(gadTop); elem.parentNode.parentNode.appendChild(gadTopDiv); elem.parentNode.parentNode.removeChild(elem.parentNode); (adsbygoogle = window.adsbygoogle || []).push({}); if (!adbChk()) { gaEvtTrk('Bannner Network', 'Adsense', 'LeaderboardTopMobile'); } } else { googletag.cmd.push(function() { googletag.display('div-swshb-top_leaderboard-1-0'); }); if (!adbChk()) { gaEvtTrk('Bannner Network', 'Snigel', elem.id); } } } var elem = document.getElementById('div-swshb-sidebar_1_left-1-0'); if (elem && window.innerWidth >= 800) { googletag.cmd.push(function() { googletag.display('div-swshb-sidebar_1_left-1-0'); }); if (!adbChk()) { gaEvtTrk('Bannner Network', 'Snigel', elem.id); } } var elem = document.getElementById('div-swshb-sidebar_right-0'); if (elem && window.innerWidth >= 1280) { googletag.cmd.push(function() { googletag.display('div-swshb-sidebar_right-0'); }); if (!adbChk()) { gaEvtTrk('Bannner Network', 'Snigel', elem.id); } } var adsToDel = []; var contentLBs = document.getElementsByClassName('dfpCLB'); if (window.innerWidth >= 1280) { for (var i = 0; i < contentLBs.length; i++) { adsToDel.push(contentLBs[i]); } } else { for (var i = 0; i < contentLBs.length; i++) { if (i>2 || window.innerWidth >= 800) { adsToDel.push(contentLBs[i]); } else { var elem = contentLBs[i]; var elemId = 'div-swshb-incontent-' + (i+1) + '_mobile-0'; elem.insertAdjacentHTML('afterbegin', '<div class="adMarker">Advertising</div><div id="' + elemId + '" style="padding-top:20px;">'); if (elem.parentNode && elem.parentNode.parentNode && elem.parentNode.parentNode.tagName.toLowerCase() == 'tr') { elem.parentNode.parentNode.style.display = "table-row"; } googletag.cmd.push(function() { googletag.display(elemId); }); if (!adbChk()) { gaEvtTrk('Bannner Network', 'Snigel', elemId); } } } } var adsToDelC = adsToDel.length; for(var i = adsToDelC; i > 0; i--) { delAd(adsToDel[i-1]); }
#   </script>
#   <script>
#    var header = document.getElementById('fixTop'); if (header) { window.onscroll = function() { var body = document.body, html = document.documentElement; var height = Math.max( body.scrollHeight, body.offsetHeight, html.clientHeight, html.scrollHeight, html.offsetHeight); if (height > window.innerHeight) { if (window.pageYOffset) { header.classList.add('fixed'); } else { header.classList.remove('fixed'); } } }; } function imgError() { this.src='/images/static/empty.png'; this.style='height: 0px'; } document.addEventListener("DOMContentLoaded", function(event) { var imgs = document.querySelectorAll('img'); for (var i = 0; i < imgs.length; i++) { imgs[i].onerror = imgError; } }); function adbHand() { var b = document.getElementsByClassName('exNet'); if (b.length > 2) { c=0; for (var i=0; i < b.length; i++) { var adEl = $(b[i]); if (adEl.attr('id') != 'wavoWrapperCenter' && (adEl.height() < 30 || adEl.css('display') == 'none')) { if (adEl.parent().attr('id') == 'topExNet') { uElem = adEl.parent().attr('id'); var bAltCheck = $.ajax( { method: 'GET', url: '/ajax/get_image.php', data: { type: 'bImg', bType: 6, bPos: 2, bFormat: 2 } } ); bAltCheck.done(function(jsonData) { if (jsonData.success) { $('#topExNet').find('div').html(jsonData.result); gaEvtTrk('Bannner View', jsonData.campaign, jsonData.tag); } }); } c++; } } if (c >= (b.length-1)) { } } }
#   </script>
#   <script>
#    var ytTimeOut = 0;function lJS(src) {var srcParts = src.split('/');var lastSrcPart = srcParts[srcParts.length-1];if (lastSrcPart.split('?').length > 1) {lastSrcPart = lastSrcPart.split('?')[0];}if (!document.getElementById('js_' + lastSrcPart)) {var a=document.createElement('script');a.async='async';a.src=src;a.id='js_' + lastSrcPart;a.crossorigin='anonymous';var s=document.getElementsByTagName('head')[0];s.appendChild(a);}}function loadYTIframe() {if (!ytPlayers.length && ytTimeOut < 1000) {ytTimeOut += 100;setTimeout(loadYTIframe, 100);} else {lJS('https://www.youtube.com/iframe_api');}}function showWavoWidget(isPassback) {if (!sideWidgetFound && !bottomWidgetFound) {if (mT && mT.length && mT.width() >= 320) {var wavoE = document.getElementsByClassName('wavo');if (wavoE.length) {var wE = false;if (window.innerWidth >= 1420 && adbChk()) {var wE = $('#wavoRight');if (wE.length) {var wEW = $('#wavoWrapperRight');} else {wE = false;}}if (!wE) {var wE = $('#wavoCenter');var wEW = $('#wavoWrapperCenter');}if (wEW.length && wE.length) {wEW.css('display', 'block');wb.q.push(['addGrid', { siteId: '377388', id : wE.attr('id') }]);bottomWidgetFound = true;var elementId = 'Wavo';if (isPassback) {elementId += 'Passback';}gaEvtTrk('Bannner Network', elementId, wE.attr('id'));} else {}}}}if (!bottomWidgetFound) {}}function isNow() {if (typeof performance !== "undefined") {return performance.now();} else {return new Date().getTime();}}var startTime = isNow();var loopTime = startTime;var fwRdy = [];var jsLoadTimeout = 0;function jsAsyncReady() {jsLoadTimeout = jsLoadTimeout + 10;if (typeof jQuery === "undefined"){if (!jqTime) {var jqTime = isNow();}if ((jqTime - loopTime) > 3000 && !fwRdy.jQFB) {lJS('/js/jquery-3.3.1.js');fwRdy.jQFB = true;}setTimeout(jsAsyncReady, jsLoadTimeout);return;} else {if (!fwRdy.lazyLoad) {lJS('/js/lazyload.min.js');fwRdy.lazyLoad = true;}if (!fwRdy.jQ) {lJS('https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js');fwRdy.jQ = true;loopTime = isNow();}}if (typeof $().emulateTransitionEnd == "undefined"){if (!bsTime) {var bsTime = isNow();}if ((bsTime - loopTime) > 3000 && !fwRdy.bsFB) {lJS('/js/bootstrap-3.3.7.js');fwRdy.bsFB = true;}setTimeout(jsAsyncReady, jsLoadTimeout);return;} else {if (!fwRdy.bootstrap) {fwRdy.bootstrap = true;loopTime = isNow();}}if (typeof $().autocomplete === "undefined"){if (!jqUITime) {var jqUITime = isNow();lJS('https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js');}if ((jqUITime - loopTime) > 3000 && !fwRdy.jQUIlocal) {lJS('/js/jquery-ui-1.12.1.js');fwRdy.jQUIlocal = true;}setTimeout(jsAsyncReady, jsLoadTimeout);return;} else {if (!fwRdy.jQUI) {loopTime = isNow();fwRdy.jQUI = true;}}lJS('/js/framework_v181029.js');if (typeof jsver === "undefined") {setTimeout(jsAsyncReady, jsLoadTimeout);return;} else {}if (typeof Mixcloud === "undefined"){if (!mcTime) {var mcTime = isNow();}if ((mcTime - loopTime) > 3000) {consoleDebug('mixcloud api load canceled after 3 seconds');} else {consoleDebug('mixcloud api not ready');setTimeout(jsAsyncReady, jsLoadTimeout);return;}}if (jsbuffer.length) {var i = jsbuffer.length;while (jsbuffer.length) {var obj = jsbuffer.shift();if (obj[0] == "ready") {$(obj[1]);}}}if (iFrameBuffer.length) {var i = iFrameBuffer.length;while (iFrameBuffer.length) {var obj = iFrameBuffer.shift();$('#' + obj[0]).prepend(obj[1]);if (obj[2]) {$(obj[2]);}}}$(document).ready(function($) {$('#storyCarouselLeft').css('display', 'inline');var ffmIfrm = $('#ffm_widget');sideWidgetFound = false;bottomWidgetFound = false;mT = $('#middleTbl');if (!adbChk() && ffmIfrm.length && window.innerWidth >= 1420) {window.featureFM_PassBack = function () {var rDiv = $('#rightDiv');var gadR2 = document.createElement('ins');gadR2.className = 'adsbygoogle adsenseAd';gadR2.style = 'display:inline-block;width:300px;height:250px;';gadR2.dataset.adClient = 'ca-pub-3535786192432916';gadR2.dataset.adSlot = '3013737322';gadR2.dataset.adFormat = 'auto';var gadRDiv = document.cr ...
# window.featureFM=function(e,t,n){var r,a,i=e.getElementsByTagName(t)[0];if(!e.getElementById(n))return a=e.createElement(t),a.id=n,a.src="//cdn.feature.fm/widgets/init.js",i.parentNode.insertBefore(a,i),window.featureFM||(r={_e:[],ready:function(e){r._e.push(e)}})}(document,"script","featurefm-widgets"),featureFM_renderWidget=function(e){function t(t){if(e.debug_mode)try{console.log(t)}catch(n){}finally{return}}featureFM.api.setApiKey(e.api_key),featureFM.api.registerNewConsumer(null,null,null,function(n,r){if(n)return void t("Feature.fm - Couldn't register");try{featureFM.api.setConsumer(r.consumer_token),featureFM.api.showWebWidget(e.container_id,e.layout,e.placement, e.keywords, e.restrictedPlatform == 'mobile' ? true : false, e.restrictedPlatform == 'web' ? true : false, e.showHeader)}catch(a){t(a)}finally{return}})},featureFM.ready=function(){featureFM_renderWidget({api_key:"f063d272c22c478ab055cd1ff1027683", container_id:"ffm_widget", placement: "web-sidebar", layout: 'vertical', keywords: ["electronica/dance", "edm", "1001tracklists.com"],debug_mode:false, restrictedPlatform: 'none', showHeader: 'TRENDING MUSIC'})};
# sideWidgetFound = true;gaEvtTrk('Bannner Network', 'featureFM', 'rightside');}showWavoWidget();$(window).resize(function() {$('.ui-autocomplete').hide();});$('[data-toggle="tooltip"]').tooltip();$(document).off('click.tab.data-api');$(document).on('click.tab.data-api', '[data-toggle="tab"]', function (e) {e.preventDefault();var tab = $($(this).attr('href'));var activate = !tab.hasClass('active');$('div.tab-content>div.tab-pane.active').removeClass('active');$('ul.nav.nav-tabs>li.active').removeClass('active');if (activate) {$(this).tab('show');}});if (adbChk()) {adbHand();} else {}});onLoadActions();if (cookiesCheck()) {if ($('#noCookieMsg')) {$('#noCookieMsg').remove();}if ($('#cookieMessage')) {$('#cookieMessage').show();}}var nua = navigator.userAgent;var isAndroid = (nua.indexOf('Mozilla/5.0') > -1 && nua.indexOf('Android ') > -1 && nua.indexOf('AppleWebKit') > -1 &&nua.indexOf('Chrome') === -1);if (isAndroid) {$('#search_selection').addClass('androidHack');}}jsAsyncReady();ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
trackNumbers = []
trackNames = []
artistNames = []

# %%
trackNamesSoup = soup.find_all("div", class_="tlToogleData")
artistNamesSoup = soup.find_all("meta", itemprop="byArtist")

# %%
for (i, trackNameItem) in enumerate(trackNamesSoup):
    trackNumbers.append(i+1)
    trackName = trackNameItem.meta['content']
    print(str(i+1) + str(". ") + trackName)
    trackNames.append(trackName)
# Out:
# 1. Lil Uzi Vert vs. TNGHT & RL Grime vs. GTA vs. NOMA$ - Money Longer vs. Pay Day (Diplo Edit)
# 2. Drake - I'm Upset
# 3. XXXTENTACION - Look At Me!
# 4. Huey vs. 3ELOUD! - Pop, Lock And Drop It (FAED Pop That Woo Edit)
# 5. Huey - Pop, Lock And Drop It
# 6. 3ELOUD! - Pop That Woo!
# 7. Ape Drums ft. Denzel Curry & Frizzo - Shellz
# 8. Sheck Wes vs. Bro Safari & Zomboy - Mo Bamba vs. Follow (Fashen Bootleg)
# 9. GTA - Saria's Turn Up
# 10. Bro Safari - Follow (Zomboy Remix)
# 11. Sheck Wes - Mo Bamba
# 12. Wuki - Dadadada (VIP Edit)
# 13. A$AP Ferg vs. Jack Ü & 2 Chainz - Work vs. Febreze (Jack Ü Mashup)
# 14. A$AP Ferg - Work
# 15. Jack Ü ft. 2 Chainz - Febreze
# 16. GTA - Saria's Turn Up
# 17. Drake - God's Plan
# 18. Eptic - The End (YOOKiE 'This Kills It Live' Edit)
# 19. BLVD. vs. Boombox Cartel - Full Chargé (Nitti Gritti Edit)
# 20. Kaaris - Chargé (Mr. Carmack Remix / Boombox Cartel Remix)
# 21. Juice WRLD - Lucid Dreams (BEAUZ Remix)
# 22. Yo Gotti ft. Nicki Minaj - Rake It Up (Diplo & Party Favor Remix)
# 23. DJ Fresh & Diplo ft. Dominique Young Unique - Earthquake
# 24. Cali Swag District - Teach Me How To Dougie
# 25. Bobby Shmurda - Hot N*gga
# 26. Ludacris ft. Mystikal & l-20 - Move Bitch
# 27. Diplo & French Montana & Lil Pump ft. Zhavia Ward - Welcome To The Party
# 28. Diplo & French Montana & Lil Pump vs. Waka Flocka Flame - Welcome To The Party (HMC DJ Tool Intro)
# 29. Diplo & French Montana & Lil Pump ft. Zhavia Ward - Welcome To The Party (Valentino Khan Remix)
